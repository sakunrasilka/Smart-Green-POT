# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'

# %% [markdown]
# Custom Data Training

# %%
# !yolo task=detect mode=train model=yolov8l.pt conf=0.25 data=../content/drive/MyDrive/PlantLeaf/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
